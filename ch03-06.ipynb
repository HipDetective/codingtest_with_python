# %% [markdown]
# ## 03-06_이차원 리스트 제대로 다루기

# %% [markdown]
# ### 이차원 리스트를 이용한 그래프 구현

# %% [markdown]
# #### 이차원 리스트 선언과 초기화

# %%
# 정점이 3개 있다고 가정(1~3 사용)
N = 3
graph = [[] for _ in range(N + 1)]
print(graph)
# Out:
# [[], [], [], []]

# %% [markdown]
# #### 그래프 데이터 저장하기

# %% [raw]
# 3 4
# 1 2 4
# 2 1 10
# 1 3 7
# 3 2 6

# %%
# 정점 수와 간선 수 입력
N, E = map(int, input().split())

# 간선 정보를 입력받아 저장
for _ in range(E):
    s, e, w = map(int, input().split())
    graph[s].append((e, w))

# %% [markdown]
# #### 그래프 데이터 가져오기

# %%
for i, _ in enumerate(graph[1:]):
    for nextNode, weight in _:
        print(f"node={i+1}, {nextNode=}, {weight=}")
# Out:
# node=1, nextNode=2, weight=4
# node=1, nextNode=3, weight=7
# node=2, nextNode=1, weight=10
# node=3, nextNode=2, weight=6
