# %% [markdown]
# ## ch02-02_디버깅 활용 사례 살펴보기

# %% [markdown]
# ### 코딩테스트를 진행하며 실수하기 쉬운 4가지 오류 찾아보기

# %%
# 결함 있는 코드 예제 / 배열의 주어진 범위의 합을 2로 나눈 몫을 구하시오.
import random

testcase = int(input())
answer = 0
A = [0] * (100001)

for i in range(0, 10001):
    A[i] = random.randrange(1, 101)

for t in range(1, testcase+1):
    start, end = map(int, input().split)

    for i in range(start, end+1):
        answer = answer + A[i]

    print(f'{testcase} {answer/2}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       8 for i in range(0, 10001):
#       9     A[i] = random.randrange(1, 101)
#      10
#      11 for t in range(1, testcase+1):
# ---> 12     start, end = map(int, input().split)
#      13
#      14     for i in range(start, end+1):
#      15         answer = answer + A[i]
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
# 오류1. 변수 초기화 오류 찾아보기
# 오류2. 반복문에서 인덱스 범위 지정 오류 찾아보기
# 오류3. 잘못된 변수 사용 오류 찾아보기
# 오류4. 파이썬 자동 형 변환 조심하기
