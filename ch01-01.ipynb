# %% [markdown]
# ## 01-01_시간 복잡도 표기법 알아보기

# %% [markdown]
# ### 시간 복잡도 정의하기

# %%
import random

findNumber = random.randrange(1, 101)  # 1~100 사이 랜덤값 생성

for i in range(1, 101):
    if i == findNumber:
        print(i)
        break
# Out:
# 43
