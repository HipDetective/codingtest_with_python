# %% [markdown]
# ## 03-01_시간 초과의 원인을 찾아 해결하기

# %%
# 일반적인 입출력 방식
a = int(input())
print(a)

# 빠른 입출력 방식
import sys

b = int(sys.stdin.readline())
sys.stdout.write(str(b) + '\n')
# Out:
# 12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       4
#       5 # 빠른 입출력 방식
#       6 import sys
#       7
# ----> 8 b = int(sys.stdin.readline())
#       9 sys.stdout.write(str(b) + '\n')
#
# KeyboardInterrupt:
